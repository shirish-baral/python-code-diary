# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('matches - matches.csv')

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head(7)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# ...

# %%
data.tail(3)
# Out:
#       id  season       city        date                team1  \
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2            toss_winner toss_decision  result  \
# 633        Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 634          Sunrisers Hyderabad    Sunrisers Hyderabad         field  normal
# 635  Royal Challengers Bangalore    Sunrisers Hyderabad           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 633           0  Sunrisers Hyderabad           22               0
# 634           0  Sunrisers Hyderabad            0               4
# 635           0  Sunrisers Hyderabad            8               0
#
#     player_of_match                  venue          umpire1        umpire2  \
# ...

# %%
data.shape
# Out:
# (636, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
pd.set_option('display.max_rows',None)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option('display.max_rows',None)

# %%
type(data['winner'])
# Out:
# pandas.core.series.Series

# %%
type(data[['team1','team2','winner']])
# Out:
# pandas.core.frame.DataFrame

# %%
data.iloc[2:4]
# Out:
#    id  season    city        date                   team1  \
# 2   3    2017  Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017  Indore  2017-04-08  Rising Pune Supergiant
#
#                    team2            toss_winner toss_decision  result  \
# 2  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 3        Kings XI Punjab        Kings XI Punjab         field  normal
#
#    dl_applied                 winner  win_by_runs  win_by_wickets  \
# 2           0  Kolkata Knight Riders            0              10
# 3           0        Kings XI Punjab            0               6
#
#   player_of_match                                   venue       umpire1  \
# 2         CA Lynn  Saurashtra Cricket Association Stadium   Nitin Menon
# 3      GJ Maxwell                  Holkar Cricket Stadium  AK Chaudhary
#
#          umpire2  umpire3
# 2      CK Nandan      NaN
# 3  C Shamshuddin      NaN

# %%
data.iloc[1:11:2]
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
# 9          Mumbai Indians               Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# ...

# %%
data.iloc[[7,8,9]]
# Out:
#    id  season    city        date                        team1  \
# 7   8    2017  Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017    Pune  2017-04-11             Delhi Daredevils
# 9  10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                     team2                  toss_winner toss_decision  result  \
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
# 8  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 9          Mumbai Indians               Mumbai Indians         field  normal
#
#    dl_applied            winner  win_by_runs  win_by_wickets player_of_match  \
# 7           0   Kings XI Punjab            0               8        AR Patel
# 8           0  Delhi Daredevils           97               0       SV Samson
# 9           0    Mumbai Indians            0               4       JJ Bumrah
#
#                                      venue       umpire1        umpire2  \
# ...

# %%
type(data.iloc[:,[4,5,10]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(data['city']=='Bangalore')
# Out:
# pandas.core.series.Series

# %%
mask = data['city']=='Bangalore'
data[mask]
# Out:
#       id  season       city        date                        team1  \
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 11    12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 16    17    2017  Bangalore  2017-04-16       Rising Pune Supergiant
# 29    30    2017  Bangalore  2017-04-27  Royal Challengers Bangalore
# 41    42    2017  Bangalore  2017-05-05              Kings XI Punjab
# 44    45    2017  Bangalore  2017-05-07  Royal Challengers Bangalore
# 56    57    2017  Bangalore  2017-05-17          Sunrisers Hyderabad
# 57    58    2017  Bangalore  2017-05-19        Kolkata Knight Riders
# 59    60    2008  Bangalore  2008-04-18        Kolkata Knight Riders
# 69    70    2008  Bangalore  2008-04-26  Royal Challengers Bangalore
# 73    74    2008  Bangalore  2008-04-28          Chennai Super Kings
# 83    84    2008  Bangalore  2008-05-05  Royal Challengers Bangalore
# 89    90    2008  Bangalore  2008-05-28  Royal Challengers Bangalore
# ...

# %%
data[mask].shape
# Out:
# (66, 18)

# %%
def get_city_match_count(city):
    mask = data['city']==city
    return data[mask].shape[0]

# %%
get_city_match_count('Delhi')
# Out:
# 60

# %%
mask1 = data['city']=='Bangalore'
mask2 = data['date']>'2010-01-01'
data[mask1 & mask2]
# Out:
#       id  season       city        date                        team1  \
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 11    12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 16    17    2017  Bangalore  2017-04-16       Rising Pune Supergiant
# 29    30    2017  Bangalore  2017-04-27  Royal Challengers Bangalore
# 41    42    2017  Bangalore  2017-05-05              Kings XI Punjab
# 44    45    2017  Bangalore  2017-05-07  Royal Challengers Bangalore
# 56    57    2017  Bangalore  2017-05-17          Sunrisers Hyderabad
# 57    58    2017  Bangalore  2017-05-19        Kolkata Knight Riders
# 180  181    2010  Bangalore  2010-03-16              Kings XI Punjab
# 183  184    2010  Bangalore  2010-03-18             Rajasthan Royals
# 191  192    2010  Bangalore  2010-03-23  Royal Challengers Bangalore
# 196  197    2010  Bangalore  2010-03-25             Delhi Daredevils
# 213  214    2010  Bangalore  2010-04-08  Royal Challengers Bangalore
# ...

# %%
kohli = data['player_of_match']=='V Kohli'
bang = data['winner']=='Royal Challengers Bangalore'
data[kohli & bang].shape[0]
# Out:
# 10

# %%
data['city'].value_counts()
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Abu Dhabi          7
# Ranchi             7
# Port Elizabeth     7
# Cuttack            7
# Raipur             6
# Sharjah            6
# Kochi              5
# Indore             5
# Kanpur             4
# Nagpur             3
# Kimberley          3
# East London        3
# Bloemfontein       2
# Name: count, dtype: int64

# %%
odisha = data['city']=='Cuttack'
data[odisha]
# Out:
#       id  season     city        date            team1                  team2  \
# 185  186    2010  Cuttack  2010-03-19  Deccan Chargers        Kings XI Punjab
# 188  189    2010  Cuttack  2010-03-21  Deccan Chargers       Delhi Daredevils
# 336  337    2012  Cuttack  2012-04-22  Deccan Chargers  Kolkata Knight Riders
# 347  348    2012  Cuttack  2012-05-01  Deccan Chargers          Pune Warriors
# 485  486    2014  Cuttack  2014-05-07  Kings XI Punjab    Chennai Super Kings
# 490  491    2014  Cuttack  2014-05-11  Kings XI Punjab  Kolkata Knight Riders
# 496  497    2014  Cuttack  2014-05-14   Mumbai Indians  Kolkata Knight Riders
#
#                toss_winner toss_decision  result  dl_applied  \
# 185        Kings XI Punjab         field  normal           0
# 188        Deccan Chargers           bat  normal           0
# 336  Kolkata Knight Riders         field  normal           0
# 347        Deccan Chargers           bat  normal           0
# ...

# %%
data['player_of_match'].value_counts()
# Out:
# player_of_match
# CH Gayle             18
# YK Pathan            16
# DA Warner            15
# AB de Villiers       15
# RG Sharma            14
# SK Raina             14
# MS Dhoni             13
# G Gambhir            13
# AM Rahane            12
# MEK Hussey           12
# V Sehwag             11
# DR Smith             11
# V Kohli              11
# SR Watson            10
# JH Kallis            10
# A Mishra              9
# KA Pollard            9
# SE Marsh              9
# SR Tendulkar          8
# RV Uthappa            7
# AT Rayudu             7
# RA Jadeja             7
# AC Gilchrist          7
# AD Russell            6
# A Nehra               6
# Harbhajan Singh       6
# BJ Hodge              6
# M Vijay               6
# UT Yadav              6
# SP Narine             6
# JP Faulkner           5
# DPMD Jayawardene      5
# SC Ganguly            5
# GJ Maxwell            5
# KC Sangakkara         5
# SL Malinga            5
# BB McCullum           5
# ...
